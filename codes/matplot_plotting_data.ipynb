# %% [markdown]
# # Plotting Data
#
# ### What we will see?
# - Matplotlib (One of the most popular plotting library for Python)
# - Seaborn (Seaborn is a statistical plotting library (beautiful default styles))
#
# ### Info.:
# * @author: Juarez Monteiro
# * @email: juarez.santos@acad.pucrs.br
# * @credits: [Python for Data Science and Machine Learning BootCamp](https://www.udemy.com/python-for-data-science-and-machine-learning-bootcamp)
#
# ### Github - jrzmnt
# * [https://github.com/jrzmnt/](github.com/jrzmnt)

# %% [markdown]
# # Let's Plot
# ![Image of Mr Burns Plotting](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTO0bUs38BKH0ZCKXXgPaJgko5iWj5Vw0YXcMwr3GhSxM1stYz-)

# %% [markdown]
# ## Importing what we need...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## First, let's take a data
#
# ### Iris flower data set
#
# ![Image of iris versicolor](http://www.spataru.at/iris-dataset-svm/iris_types.jpg)
#
#
# > The Iris flower data set or Fisher's Iris data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems as an example of linear discriminant analysis [1].<br><br> [1] R. A. Fisher (1936). "The use of multiple measurements in taxonomic problems". Annals of Eugenics 7, 179–188.
#
#
# ```py
# >import seaborn as sns
# >sns.set(style="ticks", color_codes=True)
# >iris = sns.load_dataset("iris")
# ```

# %%
sns.set(style='ticks', color_codes=True)
iris = sns.load_dataset('iris')

# %% [markdown]
# ## Python with Matplotlib
#
# ### Official website - [Matplotlib](https://matplotlib.org/)
#
# #### how to install?
# ```sh
# conda install matplotlib
# pip install matplotlib
# ```

# %%
x = np.linspace(0,5,11)
x
# Out:
# array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ])

# %%
y = x ** 2
y
# Out:
# array([  0.  ,   0.25,   1.  ,   2.25,   4.  ,   6.25,   9.  ,  12.25,
#         16.  ,  20.25,  25.  ])

# %%
# Functional Method

plt.plot(x,y)
plt.show()

# %%
# Shift+tab
plt.plot(x,y, 'r')
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('My Title')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

plt.subplot(1,2,2)
plt.plot(y,x, 'b')

plt.show()

# %%
# Object Oriented Method

# Creating a figure object
fig = plt.figure()

# - left, bottom, width, height -
axes = fig.add_axes([0.1,0.1,0.8,0.8])

#axes.plot(x,y)

# adding labels
#axes.set_xlabel('X Label')
#axes.set_ylabel('Y Label')
#axes.set_title('My Title')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes2.plot(y,x)

# %%
# Subplots OO

axes = fig.add_axes([0.1,0.1,0.8,0.8])
fig, axes = plt.subplots(nrows=1,ncols=3)

#for current_ax in axes:
#    current_ax.plot(x,y)

axes[0].plot(x,y,'o')
axes[0].set_title('First')

axes[1].plot(y,x,'r')
axes[1].set_title('Second')

# Automatically adjust subplot parameters to give specified padding.
plt.tight_layout()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2, label='X Squared', color='purple', linewidth=5, alpha=0.5)
ax.plot(x,x**3, label='X Cubed', color='#FF8C00')


ax.legend()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', lw=3, linestyle='steps')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y, color='purple', lw=3, linestyle='--', marker='o', markersize=8,
       markerfacecolor='yellow', markeredgewidth=2, markeredgecolor='red')

# %% [markdown]
# ## Python with Seaborn
#
# ### Official website - [Seaborn](https://seaborn.pydata.org/)
#
# #### how to install?
# ```sh
# conda install seaborn
# pip install seaborn
# ```

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris.keys()
# Out:
# Index([u'sepal_length', u'sepal_width', u'petal_length', u'petal_width',
#        u'species'],
#       dtype='object')

# %%
# Distribution

#sns.distplot(iris['sepal_length'])
sns.distplot(iris['sepal_width'], kde=False, bins=15)

# %%
sns.jointplot(x='sepal_length',y='sepal_width', data=iris)

# %%
sns.jointplot(x='sepal_length',y='sepal_width', data=iris, kind='hex', )

# %%
sns.jointplot(x='sepal_length',y='sepal_width', data=iris, kind='reg')

# %%
sns.jointplot(x='sepal_length',y='sepal_width', data=iris, kind='kde')

# %%
sns.pairplot(iris, hue='species')

# %%
sns.pairplot(iris, hue='species', palette='coolwarm')

# %%
g = sns.PairGrid(iris, hue="species", palette="GnBu_d")
g.map(plt.scatter, s=80, edgecolor="white")
g.add_legend();

# %%
sns.distplot(iris['sepal_length'], kde=False, bins=20)

# %%
sns.kdeplot(iris['sepal_width'])

# %%
sns.barplot(x='species', y='sepal_width', data=iris)

# %%
sns.barplot(x='species', y='sepal_length', data=iris)

# %%
sns.countplot(x='species', data=iris)

# %%
sns.boxplot(x='species', y='sepal_width', data=iris)

# %%
sns.stripplot(x='species', y='sepal_width', data=iris, jitter=True)

# %%
iris_corr = iris.corr()
iris_corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris_corr, annot=True, cmap='coolwarm')

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights_pivot = flights.pivot_table(index='month', columns='year', values='passengers')
flights_pivot
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(flights_pivot)

# %%
sns.heatmap(flights_pivot, cmap='magma', linecolor='white', linewidths=1)

# %%
sns.heatmap(flights_pivot, cmap='coolwarm', linecolor='white', linewidths=2)

# %%
# cluster hierárquico

sns.clustermap(flights_pivot, linewidths=2, cmap='coolwarm', standard_scale=1)

# %%
sns.lmplot(x='petal_length', y='petal_width', data=iris, hue='species', 
           markers=['o','v','x'], scatter_kws={'s':50})

# %%
sns.lmplot(x='petal_length', y='petal_width', data=iris, col='species', aspect=0.9)

# %% [markdown]
# ![](http://html.orange-idea.com/barton/wp-content/uploads/2015/10/si048.png)
